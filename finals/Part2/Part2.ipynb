# %%
import time
import datetime 
from datetime import datetime
# %matplotlib inline
from matplotlib import pyplot as plt
import csv
import numpy as np
import pandas as pd
import nltk

# %%
import plotly.plotly as py
import pandas as pd

df_airports = pd.read_csv('C:/Users/pruth/Desktop/Datasets/flights.csv/airports.csv')


df_flight_paths =pd.read_csv('C:/Users/pruth/Desktop/Datasets/flights.csv/flights.csv',low_memory=False)
df_flight_paths.head(2)
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0            ANC                 SEA                    5      ...
# 1            LAX                 PBI                   10      ...
#
#    ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 0         408.0          -22.0         0          0                  NaN
# 1         741.0           -9.0         0          0                  NaN
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0               NaN             NaN            NaN                  NaN
# 1               NaN             NaN            NaN                  NaN
#
#    WEATHER_DELAY
# 0            NaN
# 1            NaN
#
# [2 rows x 31 columns]

# %%
flights_new = pd.merge(df_flight_paths, df_airports, left_on='AIRLINE', right_on='IATA_CODE', how='left')
flights_new.drop('IATA_CODE', axis=1, inplace=True)
flights_new.rename(columns={'AIRLINE_x': 'AIRLINE_CODE','AIRLINE_y': 'AIRLINE'}, inplace=True)

# %%
occurance={}


for word in flights_new.DESTINATION_AIRPORT:
    if word not in occurance:
        occurance[word] = 1
    else:
        occurance[word] = occurance[word] + 1
dict1={}
for a,b in occurance.items():
     if a.isalpha():
            dict1[b] = a
#to find out the most busiest airport

# %%
sorted_dict1 = sorted(dict1.items(), key=operator.itemgetter(1), reverse=True)
sorted_newocc
with open('MaxDepartureAirports.csv', 'w') as csvfile:
    fieldnames = ['Airports', 'Scheduled Flights']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for (a,z) in sorted_dict1:
            writer.writerow({'Airports':a,'Scheduled Flights': z})

# %%
from numpy import *
import operator
newocc = dict(sorted(occurance.items(), key=operator.itemgetter(1), reverse=True)[:10])

sorted_newocc = sorted(newocc.items(), key=operator.itemgetter(1), reverse=True)
sorted_newocc
# Out:
# [('ATL', 346904),
#  ('ORD', 285906),
#  ('DFW', 239582),
#  ('DEN', 196010),
#  ('LAX', 194696),
#  ('SFO', 147966),
#  ('PHX', 146812),
#  ('IAH', 146683),
#  ('LAS', 133198),
#  ('MSP', 112128)]

# %%
with open('MaxDepartureAirportsTop10.csv', 'w') as csvfile:
    fieldnames = ['Airports', 'Scheduled Flights']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for (a,z) in sorted_newocc:
            writer.writerow({'Airports':a,'Scheduled Flights': z})

# %%
Arrival = flights[['ORIGIN_AIRPORT', 'DAY_OF_WEEK', 'MONTH']]
arrival_numbers = Arrival[['ORIGIN_AIRPORT', 'DAY_OF_WEEK']].groupby('ORIGIN_AIRPORT').size().reset_index()
arrival_numbers.columns = ['AIRPORT', 'NO_OF_FLIGHTS']
arrival_numbers = arrival_numbers.sort_index(by = 'NO_OF_FLIGHTS')
arrival_numbers.tail(10)
# Out:
# C:\Users\pruth\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: FutureWarning:
#
# by argument to sort_index is deprecated, pls use .sort_values(by=...)
#     AIRPORT  NO_OF_FLIGHTS
# 522     MSP         112117
# 480     LAS         133181
# 457     IAH         146622
# 545     PHX         146815
# 584     SFO         148008
# 482     LAX         194673
# 391     DEN         196055
# 392     DFW         239551
# 534     ORD         285884
# 326     ATL         346836

# %%
arrival_numbers[-10:].to_csv('MaxArrivalAirports.csv')

# %%
new_airport= df_airports[['LATITUDE','LONGITUDE','IATA_CODE']]
# new_arrival = pd.merge(arrival_numbers, new_airport, on='AIRPORT', how='outer')
# new_arrival
arrs = arrival_numbers.merge(df_airports,how='left', left_on='AIRPORT', right_on='IATA_CODE')
arrs.drop('IATA_CODE',axis=1,inplace=True)

# %%
arr_max = arrs.nlargest(10, 'NO_OF_FLIGHTS', keep='first')
arr_max
# Out:
#     AIRPORT_x  NO_OF_FLIGHTS  \
# 627       ATL         346836
# 626       ORD         285884
# 625       DFW         239551
# 624       DEN         196055
# 623       LAX         194673
# 622       SFO         148008
# 621       PHX         146815
# 620       IAH         146622
# 619       LAS         133181
# 618       MSP         112117
#
#                                             AIRPORT_y               CITY  \
# 627  Hartsfield-Jackson Atlanta International Airport            Atlanta
# 626              Chicago O'Hare International Airport            Chicago
# 625           Dallas/Fort Worth International Airport  Dallas-Fort Worth
# 624                      Denver International Airport             Denver
# 623                 Los Angeles International Airport        Los Angeles
# 622               San Francisco International Airport      San Francisco
# 621          Phoenix Sky Harbor International Airport            Phoenix
# ...

# %%
import plotly.plotly as py
import pandas as pd

df = arrs
df.head()


df['text'] = df['AIRPORT_x'] + '' + df['CITY'] + ', ' + df['STATE'] + '' + 'Arrivals: ' + df['NO_OF_FLIGHTS'].astype(str)

scl = [ [0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
    [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"] ]

data = [ dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df['LONGITUDE'],
        lat = df['LATITUDE'],
        text = df['text'],
        mode = 'markers',
        marker = dict(
            size = 8,
            opacity = 0.8,
            reversescale = True,
            autocolorscale = False,
            symbol = 'square',
            line = dict(
                width=1,
                color='rgba(102, 102, 102)'
            ),
            colorscale = scl,
            cmin = 0,
            color = df['NO_OF_FLIGHTS'],
            cmax = df['NO_OF_FLIGHTS'].max(),
            colorbar=dict(
                title="Arriving flights"
            )
        ))]

layout = dict(
        title = 'Most Arrival flights traffic at US airports',
        colorbar = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = "rgb(250, 250, 250)",
            subunitcolor = "rgb(217, 217, 217)",
            countrycolor = "rgb(217, 217, 217)",
            countrywidth = 0.5,
            subunitwidth = 0.5
        ),
    )

fig = dict( data=data, layout=layout )
py.image.save_as(fig, filename='Part2Plot.png')
py.iplot( fig, validate=False, filename='d3-airports' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~thakar.p/20.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # part2plot.png

# %% [markdown]
# # From this image we can specify the airports having most number of arriving flights and the epi centers of air traffic in USA.

# %%
d = pd.read_csv('MaxDepartureAirportsTop10.csv')
d.dropna()
d.tail()
# Out:
#   Airports  Scheduled Flights
# 5      SFO             147966
# 6      PHX             146812
# 7      IAH             146683
# 8      LAS             133198
# 9      MSP             112128

# %%
dep = d.merge(df_airports,how='left', left_on='Airports', right_on='IATA_CODE')
dep.drop('IATA_CODE',axis=1,inplace=True)
dep
# Out:
#   Airports  Scheduled Flights  \
# 0      ATL             346904
# 1      ORD             285906
# 2      DFW             239582
# 3      DEN             196010
# 4      LAX             194696
# 5      SFO             147966
# 6      PHX             146812
# 7      IAH             146683
# 8      LAS             133198
# 9      MSP             112128
#
#                                             AIRPORT               CITY STATE  \
# 0  Hartsfield-Jackson Atlanta International Airport            Atlanta    GA
# 1              Chicago O'Hare International Airport            Chicago    IL
# 2           Dallas/Fort Worth International Airport  Dallas-Fort Worth    TX
# 3                      Denver International Airport             Denver    CO
# 4                 Los Angeles International Airport        Los Angeles    CA
# 5               San Francisco International Airport      San Francisco    CA
# 6          Phoenix Sky Harbor International Airport            Phoenix    AZ
# ...

# %%
df = dep
df.head()

df['text'] = df['Airports'] + '' + df['CITY'] + ', ' + df['STATE'] + '' + 'Arrivals: ' + df['Scheduled Flights'].astype(str)

scl = [ [0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
    [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"] ]

data = [ dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df['LONGITUDE'],
        lat = df['LATITUDE'],
        text = df['text'],
        mode = 'markers',
        marker = dict(
            size = 8,
            opacity = 0.8,
            reversescale = True,
            autocolorscale = False,
            symbol = 'round',
            line = dict(
                width=1,
                color='rgba(102, 102, 102)'
            ),
            colorscale = scl,
            cmin = 0,
            color = df['Scheduled Flights'],
            cmax = df['Scheduled Flights'].max(),
            colorbar=dict(
                title="Departing flights"
            )
        ))]

layout = dict(
        title = 'Most Departure flights traffic at US airports',
        colorbar = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = "rgb(250, 250, 250)",
            subunitcolor = "rgb(217, 217, 217)",
            countrycolor = "rgb(217, 217, 217)",
            countrywidth = 0.5,
            subunitwidth = 0.5
        ),
    )

fig = dict( data=data, layout=layout )
py.image.save_as(fig, filename='Part2Plot2.png')
py.iplot( fig, validate=False, filename='d3-airports' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~thakar.p/20.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # If you pull this repositort you can hover over the circles in figure and find out the details of each circle

# %% [markdown]
# # From this image we know about the Top 10 airports with most Departing flights in USA and the most busiest being Atlanta's Hartsfield-Jackson Atlanta International Airport.
